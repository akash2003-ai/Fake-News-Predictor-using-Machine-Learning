# %% [markdown]
# ## fake news predictor

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd

# Sample training data (manually added)
df= pd.read_csv(r"C:\Users\bhara\Desktop\python\fake news detector project\fake_news_dataset.csv")
texts = df['news'].values
labels = df['label'].values

# Step 1: Preprocess
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# Step 2: Train model
model = LogisticRegression()
model.fit(X, labels)

# Step 3: Take input and predict
headline = input("📰 Enter a news headline: ")
headline_vec = vectorizer.transform([headline])
prediction = model.predict(headline_vec)

print(" This news is:", "FAKE " if prediction[0] == "FAKE" else "REAL ")
# Out:
#  This news is: REAL
